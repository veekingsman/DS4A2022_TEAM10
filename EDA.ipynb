# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
ethnicity_df = pd.read_csv('US_Census_Bureau_Selected_Population_Profile.csv')
ethnicity_df = ethnicity_df.dropna(axis='columns')
ethnicity_df.head()
# Out:
#    year  geo_id        geographic area name                  ethnicity  \
# 0  2018   12086  Miami-Dade County, Florida  Black or African American
# 1  2017   12086  Miami-Dade County, Florida  Black or African American
# 2  2016   12086  Miami-Dade County, Florida  Black or African American
# 3  2018   12086  Miami-Dade County, Florida             White American
# 4  2017   12086  Miami-Dade County, Florida             White American
#
#    estimate  bp_married  bp_other_family  ap_married  ap_other_family
# 0     96151        4106            15048       35922            41075
# 1     90624        5104            14631       35251            35638
# 2     92487        5119            14618       34200            38550
# 3    477599       25047            31195      298536           122821
# 4    466317       27643            29626      281059           127989

# %%
poverty_df = pd.read_csv('uscensus_poverty_status_by_tenure_miamidade.csv')
poverty_df.head()
# Out:
#    year  bp_total_income  bp_total_errormargin  bp_owner_income  \
# 0  2018            82235                  4497            25288
# 1  2017            82351                  4368            23504
# 2  2016            89022                  5574            25026
# 3  2015            94091                  4672            27747
# 4  2014            97361                  5536            27645
#
#   bp_owner_errormargin  bp_renter_income bp_renter_errormargin  \
# 0                 2196             56947                  4029
# 1                2,696             58847                 4,201
# 2                 2360             63996                  5034
# 3                 2545             66344                  4093
# 4                 2576             69716                  4229
#
#    ap_total_income ap_total_errormargin  ap_owner_income ap_owner_errormargin  \
# 0           540291                 8645           320537                 7969
# ...

# %%
eviction_df = pd.read_csv('evictionlab_miamidade.csv')
eviction_df = eviction_df.fillna(0)
eviction_df = eviction_df.rename(columns={'cofips':'geo_id'})
eviction_df
# Out:
#              fips  geo_id               tract             county    state  \
# 0     12086004607   12086  Census Tract 46.07  Miami-Dade County  Florida
# 1     12086000410   12086   Census Tract 4.10  Miami-Dade County  Florida
# 2     12086014600   12086    Census Tract 146  Miami-Dade County  Florida
# 3     12086014200   12086    Census Tract 142  Miami-Dade County  Florida
# 4     12086006713   12086  Census Tract 67.13  Miami-Dade County  Florida
# ...           ...     ...                 ...                ...      ...
# 8806  12086014900   12086    Census Tract 149  Miami-Dade County  Florida
# 8807  12086000131   12086   Census Tract 1.31  Miami-Dade County  Florida
# 8808  12086019400   12086    Census Tract 194  Miami-Dade County  Florida
# 8809  12086008207   12086  Census Tract 82.07  Miami-Dade County  Florida
# 8810  12086017200   12086    Census Tract 172  Miami-Dade County  Florida
#
#       year      type  filings  filing_rate  threatened  threatened_rate  \
# ...

# %%
weather_df = pd.read_csv('weather_events_miamidade.csv')
df = weather_df
df
# Out:
#      EVENT_ID        CZ_NAME_STR BEGIN_LOCATION  BEGIN_DATE  BEGIN_TIME  \
# 0      565140     MIAMI-DADE CO.     LEMON CITY  02/28/2015        1400
# 1      595906     MIAMI-DADE CO.   IVES ESTATES  08/26/2015        1455
# 2      596775     MIAMI-DADE CO.     LEMON CITY  08/30/2015         243
# 3      598706  MIAMI-DADE (ZONE)                 09/24/2015         700
# 4      598708  MIAMI-DADE (ZONE)                 09/25/2015         500
# ..        ...                ...            ...         ...         ...
# 177    988797     MIAMI-DADE CO.    MIAMI BEACH  10/22/2021        1600
# 178    988844     MIAMI-DADE CO.    SOUTH MIAMI  11/05/2021         400
# 179    989122     MIAMI-DADE CO.     LEMON CITY  11/05/2021         500
# 180    989127     MIAMI-DADE CO.     LEMON CITY  11/18/2021        1720
# 181    989128     MIAMI-DADE CO.    MIAMI BEACH  11/18/2021        1800
#
#         EVENT_TYPE MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  ...  \
# ...
